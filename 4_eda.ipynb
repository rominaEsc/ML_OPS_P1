# %%
import pandas as pd
import wordcloud
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

# %%
movies = pd.read_csv("data/movies_etl.csv", sep=",")
genres = pd.read_csv("data/genres.csv",sep =",")
movies_genres = pd.read_csv("data/movies_genres.csv",sep =",")
ml_df = pd.read_csv("data/ml_df.csv",sep =",")
sist_recomendacion_df = pd.read_csv("data/sist_recomendacion_df.csv",sep =",")

# %% [markdown]
# ------

# %% [markdown]
# EDA

# %%
text = sist_recomendacion_df.fillna(' ')
text['title'] = text['title'].astype('str')
text['overview']= text ['overview'].astype('str')
text['text'] = text['title']+ ' ' +text['overview']
stopwords = STOPWORDS

# %%
text_title = ' '.join(text['title'])
text_overview = ' '.join(text['overview'])

# %%
text.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43718 entries, 0 to 43717
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   title     43718 non-null  object
#  1   overview  43718 non-null  object
#  2   name      43718 non-null  object
#  3   text      43718 non-null  object
# dtypes: object(4)
# memory usage: 1.3+ MB

# %%
WC = WordCloud(
    background_color='white',
    stopwords=stopwords,
)

# %%
for i in [text_title,text_overview]:
    WC.generate(i)
    plt.figure()
    plt.imshow(WC)
    plt.axis('off')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 for i in [text_title,text_overview]:
# ----> 2     WC.generate(i)
#       3     plt.figure()
#       4     plt.imshow(WC)
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\site-packages\wordcloud\wordcloud.py:639, in WordCloud.generate(self, text)
#     624 def generate(self, text):
#     625     """Generate wordcloud from text.
#     626
#     627     The input "text" is expected to be a natural text. If you pass a sorted
#    (...)
#     637     self
#     638     """
# --> 639     return self.generate_from_text(text)
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\site-packages\wordcloud\wordcloud.py:620, in WordCloud.generate_from_text(self, text)
#     603 def generate_from_text(self, text):
#     604     """Generate wordcloud from text.
#     605
#     606     The input "text" is expected to be a natural text. If you pass a sorted
#    (...)
#     618     self
#     619     """
# --> 620     words = self.process_text(text)
#     621     self.generate_from_frequencies(words)
#     622     return self
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\site-packages\wordcloud\wordcloud.py:584, in WordCloud.process_text(self, text)
#     582 words = re.findall(regexp, text, flags)
#     583 # remove 's
# --> 584 words = [word[:-2] if word.lower().endswith("'s") else word
#     585          for word in words]
#     586 # remove numbers
#     587 if not self.include_numbers:
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\site-packages\wordcloud\wordcloud.py:584, in <listcomp>(.0)
#     582 words = re.findall(regexp, text, flags)
#     583 # remove 's
# --> 584 words = [word[:-2] if word.lower().endswith("'s") else word
#     585          for word in words]
#     586 # remove numbers
#     587 if not self.include_numbers:
#
# KeyboardInterrupt:

# %% [markdown]
# ------
